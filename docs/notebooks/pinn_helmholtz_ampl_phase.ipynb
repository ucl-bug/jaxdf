# %% [markdown]
# # Solving Helmholtz equation with PINNs

# %%
from matplotlib import pyplot as plt

from jaxdf.geometry import Domain
from jaxdf import operators as jops
from jaxdf.core import operator
from jax import numpy as jnp
import jax

# %% [markdown]
# The equation we want to simulate is
#
# $$
# \left(\nabla^2 - \frac{\omega^2}{c^2} \right)u = - i\omega S_M
# $$
#
# Furthermore, to enforce the Sommerfield radiation conditions, the components of the spatial differential operators are modified as [[1]](http://oomph-lib.maths.man.ac.uk/doc/pml_helmholtz/scattering/latex/refman.pdf):
#
# $$
# \partial_{x_j} = \frac{\partial_{x_j}}{\gamma_j}
# $$
#
# where
#
# $$
# \gamma_j = 1 + \frac{\sigma_j(x)}{k_0}, \qquad \sigma_j(x) = \begin{cases}
# \frac{\sigma^*\|x_j - \Delta_{PML}\|^\alpha}{\Delta_{PML}}, & \|x\| > \Delta_{PML}\\
# 0, & \text{otherwise} \\
# \end{cases}$$
#
# Let's start by building up the $\sigma$ function

# %%
domain = Domain((256, 256), (1., 1.))
omega = .25

# %%
from jaxdf.discretization import Coordinate
from jaxdf.core import Field

coordinate_discr = Coordinate(domain)
X = Field(coordinate_discr, params={}, name="X")

# Define PML Function
delta_pml = 100.
def sigma(X):
    on_pml = jops.elementwise(
        lambda x: jnp.where(
            jnp.abs(x) > delta_pml,
            (jnp.abs(jnp.abs(x)-delta_pml)/(128. - delta_pml)), 
            0.)
    )
    return 4.*on_pml(X)**2

def pml_factor(X):
    return 1./(1 + 1j*sigma(X)/omega)

# Define laplacian with PML
def laplacian(u, x):
    pml = pml_factor(x)
    grad_u = jops.gradient(u)
    mod_grad_u = grad_u*pml
    mod_diag_jacobian = jops.diag_jacobian(mod_grad_u)*pml
    return jops.sum_over_dims(mod_diag_jacobian)

@operator()
def helmholtz(u, c, x):
    # Get the modified laplacian
    L = laplacian(u, x)
    
    # Add the wavenumber term
    k = ((omega/c)**2)*u
    
    return L + k

# %%
from jaxdf.discretization import Arbitrary, UniformField
from jax.experimental import stax
from jax import random

seed = random.PRNGKey(42)

# Make a neural network for the field discretization
Sin = stax.elementwise(jnp.sin)
init_random_params, predict_p = stax.serial(
    stax.Dense(256), 
    Sin, 
    stax.Dense(256), 
    Sin, 
    stax.Dense(256), 
    Sin, 
    stax.Dense(256), 
    Sin, 
    stax.Dense(256), 
    Sin, 
    stax.Dense(2)
)

def init_params(seed, domain):
    return init_random_params(seed, (len(domain.N),))[1]

def get_fun(params, x):
    x = 30*x/128.
    p = predict_p(params, x)
    return jnp.asarray([jnp.abs(p[0])*jnp.exp(p[1]*1j),])

u_discr = Arbitrary(domain, get_fun, init_params)
u_params, u = u_discr.random_field(seed, name='u')

# Narrow gaussian pulse as source
def init_params(seed, domain):
    return {}

def gaussian_func(params, x):
    x = x + jnp.asarray([75,75])
    return jnp.expand_dims(jnp.exp(-jnp.sum(x**2)/8) + 0*1j, -1)

src_discr = Arbitrary(domain, gaussian_func, init_params)
src_params, src = src_discr.random_field(seed, name='src')

# Arbitrary SOS map

'''
Sin = stax.elementwise(jnp.tanh)
Treshold_shift = stax.elementwise(jax.nn.sigmoid)
Relu = stax.elementwise(jax.nn.relu)
init_random_params, predict_p = stax.serial(
    stax.Dense(128), 
    Relu, 
    stax.Dense(128), 
    Relu, 
    stax.Dense(128), 
    Relu, 
    stax.Dense(128), 
    Relu, 
    stax.Dense(128), 
    Sin, 
    stax.Dense(1),
    Treshold_shift
)

def init_params(seed, domain):
    return init_random_params(seed, (len(domain.N),))[1]

def get_fun(params, x):
    p = predict_p(params, x)*(1-jax.nn.sigmoid(jnp.abs(x[0]) - 50))*(1-jax.nn.sigmoid(jnp.abs(x[1]) - 50)) + 1
    return p

c_discr = Arbitrary(domain, get_fun, init_params)
c_params, c = c_discr.random_field(seed, name='c')
'''

# Arbitrary Speed of Sound map
def init_params(seed, domain):
    return {}

def sos_func(params, x):
    x = x - jnp.asarray([32,32])
    x = jnp.exp(-jnp.sum(x**2)/2048)
    x = jnp.where(jnp.abs(x)>0.5, 1., 0.)
    return jnp.expand_dims(x + 1., -1)
                  
c_discr = Arbitrary(domain, sos_func, init_params)
c_params, c = c_discr.random_field(seed, name='c')

# %%
sos_map = c_discr.get_field_on_grid()(c_params)
plt.imshow(sos_map)
plt.colorbar()

# %%
src_map = src_discr.get_field_on_grid()({})
plt.imshow(src_map.real)
plt.colorbar()

# %%
src_map = u_discr.get_field_on_grid()(u_params)
plt.imshow(src_map.real)
plt.colorbar()

# %%
src_map.shape
# Out:
# (256, 256, 1)

# %%
Hu = helmholtz(u=u, c=c, x=X)
global_params = Hu.get_global_params()

# %%
f = Hu.get_field(0)

# %%
x = jnp.asarray([2.,2.])
f(global_params,{"u": u_params, "c":c_params, "x":{}}, x).shape
# Out:
# (1,)

# %%
src_map = Hu.get_field_on_grid(0)(global_params,{"u": u_params, "c":c_params, "x":{}})
plt.imshow(src_map.real)
plt.colorbar()

# %%
boundary_sampler = domain.boundary_sampler
x = boundary_sampler(seed, 128)
plt.scatter(x[:,0],x[:,1])

# %%
domain_sampler = domain.domain_sampler()
x = domain_sampler(seed, 256)
plt.scatter(x[:,0],x[:,1])

# %%
from jax import value_and_grad

f = Hu.get_field(0)
def helmholtz_fun(params, x):
    params_u, params_c = params
    return f(global_params,{"u": params_u, "c":params_c, "x":{}}, x)

# Defining losses
field = u_discr.get_field()
source_f = src.get_field()
def boundary_loss(params, seed, batchsize):
    x = boundary_sampler(seed, batchsize)
    field_val = jax.vmap(field, in_axes=(None,0))(params[0],x)
    return jnp.mean(jnp.abs(field_val)**2)

def domain_loss(params, seed, batchsize):
    x = domain_sampler(seed, batchsize)
    helm_val = jax.vmap(helmholtz_fun, in_axes=(None,0))(params,x)
    src_val = jax.vmap(source_f, in_axes=(None,0))(None, x)
    return jnp.sum(jnp.abs(src_val + helm_val))

def target_loss(params):
    x = jnp.asarray([0.,-75.])
    helm_val = helmholtz_fun(params,x)
    return -jnp.sum(jnp.abs(helm_val))

bound_valandgrad = jax.value_and_grad(boundary_loss)
domain_valandgrad = jax.value_and_grad(domain_loss)
target_valandgrad = jax.value_and_grad(target_loss)

def field_update(u_p, c_p, seed):
    seeds = random.split(seed, 2)
    params = [u_p, c_p]
    
    # losses f
    boundary_loss, b_gradient = bound_valandgrad(params, seeds[0], batch_size)
    domain_loss, d_gradient = domain_valandgrad(params, seeds[1], batch_size)
    gradient = tree_multimap(lambda x,y: 0.01*x+y, b_gradient, d_gradient)
    
    return boundary_loss, domain_loss, gradient[0]

def sos_update(u_p, c_p, seed):
    seeds = random.split(seed, 2)
    
    def one_step_loss(c_p):
        params = [u_p, c_p]
        
        # losses
        boundary_loss, b_gradient = bound_valandgrad(params, seeds[0], batch_size)
        domain_loss, d_gradient = domain_valandgrad(params, seeds[1], batch_size)
        gradient = tree_multimap(lambda x,y: 0.01*x+y, b_gradient, d_gradient)

        # Update field with simple SGD
        grad_fun = lambda x,y: x - 0.1*y
        params[0] = jax.tree_multimap(grad_fun,params[0],gradient[0])
    
        # Find the new field loss
        return target_loss(params)
    
    # Find gradient
    lossval, gradient = jax.value_and_grad(one_step_loss)(c_p)
    
    return lossval, gradient

@jax.jit
def update(opt_state, seed, k):
    seeds = random.split(seed, 2)
    u_p, c_p = get_params(opt_state)
    
    # Physics loss
    bl, domain_loss, u_grad = field_update(u_p, c_p, seeds[0])
    #targ_loss, c_grad = sos_update(u_p, c_p, seeds[1])
    targ_loss = 0.
    
    # Update parameters
    gradient = [u_grad, jax.tree_map(lambda x: x*0,c_p)]
    
    return bl, domain_loss, targ_loss, update_fun(k, gradient, opt_state)

# %%
import wandb

# %%
def log_image(wandb, field, name, step):
    plt.imshow(field[...,0].real, cmap='bone')
    plt.colorbar()
    img = wandb.Image(plt)
    wandb.log({name: img}, step=step)
    plt.close()

# %%
from jax.experimental import optimizers
from jax.tree_util import tree_multimap
from jax import jit
from tqdm import tqdm

losshistory = []
batch_size = 256

init_fun, update_fun, get_params = optimizers.adam(.0001)
opt_state = init_fun([u_params, c_params])

pbar = tqdm(range(100000))
tol = 1e-3
rng = seed

wandb.init(project="helmholtz-pinn")


boundary_loss_h = 0.
domain_loss_h = 0.
targ_loss_h = 0.
f_grid = u_discr.get_field_on_grid()
for k in pbar:
    rng, seed = random.split(rng,2)
    bl, domain_loss, targ_loss, opt_state = update(opt_state, seed, k)
    losshistory.append(domain_loss)

    # For logging
    boundary_loss_h = boundary_loss_h + bl
    domain_loss_h = domain_loss_h + domain_loss
    targ_loss_h = targ_loss_h + targ_loss
    
    if (k+1) % 500 == 0:
        boundary_loss_h = boundary_loss_h / 500.
        domain_loss_h = domain_loss_h / 500.
        targ_loss_h = targ_loss_h/500.
        wandb.log(
            {
                'boundary_loss': boundary_loss_h, 
                'domain_loss': domain_loss_h,
                'target_loss': targ_loss_h
            }, step=k)
        pbar.set_description("B: {:01.4f} | D: {:01.4f} | T: {:01.4f}".format(
            jnp.log10(boundary_loss_h), 
            jnp.log10(domain_loss_h),
            jnp.log10(-targ_loss_h)
        ))
        boundary_loss_h = 0.
        domain_loss_h = 0.
        
        # Logging image
        f_grid = u_discr.get_field_on_grid()
        V = f_grid(get_params(opt_state)[0])
        log_image(wandb, V, "wavefield", k)
        
        c_grid = c_discr.get_field_on_grid()
        V = c_grid(get_params(opt_state)[1])
        log_image(wandb, V, "sos", k)
# Out:
#   0%|                         | 0/100000 [00:00<?, ?it/s]wandb: Currently logged in as: rpfeynman (use `wandb login --relogin` to force relogin)
# /home/antonios/anaconda3/envs/jaxdf/lib/python3.8/site-packages/IPython/html.py:12: ShimWarning: The `IPython.html` package has been deprecated since IPython 4.0. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   warn("The `IPython.html` package has been deprecated since IPython 4.0. "
# wandb: wandb version 0.12.1 is available!  To upgrade, please run:
# wandb:  $ pip install wandb --upgrade
#
# CondaError: Expected exactly one `egg-info` directory in '/home/antonios/repos/jaxdiff', via egg-link 'lib/python3.8/site-packages/jaxdf.egg-link'. Instead found: ('jde.egg-info', 'jaxdiff.egg-info', 'jaxdf.egg-info').  These are often left over from legacy operations that did not clean up correctly.  Please remove all but one of these.
#                 Tracking run with wandb version 0.12.0<br/>
#                 Syncing run <strong style="color:#cdcd00">different-waterfall-101</strong> to <a href="https://wandb.ai" target="_blank">Weights & Biases</a> <a href="https://docs.wandb.com/integrations/jupyter.html" target="_blank">(Documentation)</a>.<br/>
#                 Project page: <a href="https://wandb.ai/rpfeynman/helmholtz-pinn" target="_blank">https://wandb.ai/rpfeynman/helmholtz-pinn</a><br/>
#                 Run page: <a href="https://wandb.ai/rpfeynman/helmholtz-pinn/runs/xlbhuaba" target="_blank">https://wandb.ai/rpfeynman/helmholtz-pinn/runs/xlbhuaba</a><br/>
#                 Run data is saved locally in <code>/home/antonios/repos/jaxdiff/docs/notebooks/wandb/run-20210909_174332-xlbhuaba</code><br/><br/>
# B: -5.1063 | D: -0.9787 | T: -inf:  16%|▏| 16499/100000 [
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/jaxdf/lib/python3.8/inspect.py in _bind(self, args, kwargs, partial)
#    2998             try:
# -> 2999                 arg_val = kwargs.pop(param_name)
#    3000             except KeyError:
#
# KeyError: 'required'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2854173/2805410602.py in <module>
#      56         c_grid = c_discr.get_field_on_grid()
#      57         V = c_grid(get_params(opt_state)[1])
# ---> 58         log_image(wandb, V, "sos", k)
#
# /tmp/ipykernel_2854173/2602833033.py in log_image(wandb, field, name, step)
#       1 def log_image(wandb, field, name, step):
#       2     plt.imshow(field[...,0].real, cmap='bone')
# ----> 3     plt.colorbar()
#       4     img = wandb.Image(plt)
#       5     wandb.log({name: img}, step=step)
#
# ~/anaconda3/envs/jaxdf/lib/python3.8/site-packages/matplotlib/pyplot.py in colorbar(mappable, cax, ax, **kw)
#    2354                                'an image (with imshow) or a contour set ('
#    2355                                'with contourf).')
# -> 2356     ret = gcf().colorbar(mappable, cax=cax, ax=ax, **kw)
#    2357     return ret
#    2358
#
# ~/anaconda3/envs/jaxdf/lib/python3.8/site-packages/matplotlib/figure.py in colorbar(self, mappable, cax, ax, use_gridspec, **kw)
#    1163             if (use_gridspec and isinstance(ax, SubplotBase)
#    1164                     and not self.get_constrained_layout()):
# -> 1165                 cax, kw = cbar.make_axes_gridspec(ax, **kw)
#    1166             else:
#    1167                 cax, kw = cbar.make_axes(ax, **kw)
#
# ~/anaconda3/envs/jaxdf/lib/python3.8/site-packages/matplotlib/colorbar.py in make_axes_gridspec(parent, location, orientation, fraction, shrink, aspect, **kw)
#    1547
#    1548     fig = parent.get_figure()
# -> 1549     cax = fig.add_subplot(ss_cb, label="<colorbar>")
#    1550     cax.set_aspect(aspect, anchor=loc_settings["anchor"], adjustable='box')
#    1551     return cax, kw
#
# ~/anaconda3/envs/jaxdf/lib/python3.8/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#     779             projection_class, pkw = self._process_projection_requirements(
#     780                 *args, **kwargs)
# --> 781             ax = subplot_class_factory(projection_class)(self, *args, **pkw)
#     782             key = (projection_class, pkw)
#     783         return self._add_axes_internal(ax, key)
#
# ~/anaconda3/envs/jaxdf/lib/python3.8/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      34         """
#      35         # _axes_class is set in the subplot_class_factory
# ---> 36         self._axes_class.__init__(self, fig, [0, 0, 1, 1], **kwargs)
#      37         # This will also update the axes position.
#      38         self.set_subplotspec(SubplotSpec._from_subplot_args(fig, args))
#
# ~/anaconda3/envs/jaxdf/lib/python3.8/site-packages/matplotlib/_api/deprecation.py in wrapper(*args, **kwargs)
#     469                 "parameter will become keyword-only %(removal)s.",
#     470                 name=name, obj_type=f"parameter of {func.__name__}()")
# --> 471         return func(*args, **kwargs)
#     472
#     473     return wrapper
#
# ~/anaconda3/envs/jaxdf/lib/python3.8/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     632
#     633         self._rasterization_zorder = None
# --> 634         self.cla()
#     635
#     636         # funcs used to format x and y - fall back on major formatters
#
# ~/anaconda3/envs/jaxdf/lib/python3.8/site-packages/matplotlib/axes/_base.py in cla(self)
#    1244
#    1245         self.grid(False)  # Disable grid on init to use rcParameter
# -> 1246         self.grid(self._gridOn, which=mpl.rcParams['axes.grid.which'],
#    1247                   axis=mpl.rcParams['axes.grid.axis'])
#    1248         props = font_manager.FontProperties(
#
# ~/anaconda3/envs/jaxdf/lib/python3.8/site-packages/matplotlib/axes/_base.py in grid(self, b, which, axis, **kwargs)
#    3064             self.xaxis.grid(b, which=which, **kwargs)
#    3065         if axis in ['y', 'both']:
# -> 3066             self.yaxis.grid(b, which=which, **kwargs)
#    3067
#    3068     def ticklabel_format(self, *, axis='both', style='', scilimits=None,
#
# ~/anaconda3/envs/jaxdf/lib/python3.8/site-packages/matplotlib/axis.py in grid(self, b, which, **kwargs)
#    1426             gridkw['gridOn'] = (not self._major_tick_kw['gridOn']
#    1427                                 if b is TOGGLE else b)
# -> 1428             self.set_tick_params(which='major', **gridkw)
#    1429         self.stale = True
#    1430
#
# ~/anaconda3/envs/jaxdf/lib/python3.8/site-packages/matplotlib/axis.py in set_tick_params(self, which, reset, **kw)
#     850                 self._major_tick_kw.update(kwtrans)
#     851                 for tick in self.majorTicks:
# --> 852                     tick._apply_params(**kwtrans)
#     853             if which in ['minor', 'both']:
#     854                 self._minor_tick_kw.update(kwtrans)
#
# ~/anaconda3/envs/jaxdf/lib/python3.8/site-packages/matplotlib/axis.py in _apply_params(self, **kw)
#     380         if 'color' in kw:
#     381             tick_kw['markeredgecolor'] = kw['color']
# --> 382         self.tick1line.set(**tick_kw)
#     383         self.tick2line.set(**tick_kw)
#     384         for k, v in tick_kw.items():
#
# ~/anaconda3/envs/jaxdf/lib/python3.8/site-packages/matplotlib/artist.py in set(self, **kwargs)
#    1152     def set(self, **kwargs):
#    1153         """A property batch setter.  Pass *kwargs* to set properties."""
# -> 1154         kwargs = cbook.normalize_kwargs(kwargs, self)
#    1155         move_color_to_start = False
#    1156         if "color" in kwargs:
#
# ~/anaconda3/envs/jaxdf/lib/python3.8/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# ~/anaconda3/envs/jaxdf/lib/python3.8/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# ~/anaconda3/envs/jaxdf/lib/python3.8/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     404     @functools.wraps(func)
#     405     def wrapper(*inner_args, **inner_kwargs):
# --> 406         arguments = signature.bind(*inner_args, **inner_kwargs).arguments
#     407         if is_varargs and arguments.get(name):
#     408             warn_deprecated(
#
# ~/anaconda3/envs/jaxdf/lib/python3.8/inspect.py in bind(self, *args, **kwargs)
#    3035         if the passed arguments can not be bound.
#    3036         """
# -> 3037         return self._bind(args, kwargs)
#    3038
#    3039     def bind_partial(self, /, *args, **kwargs):
#
# ~/anaconda3/envs/jaxdf/lib/python3.8/inspect.py in _bind(self, args, kwargs, partial)
#    2997             param_name = param.name
#    2998             try:
# -> 2999                 arg_val = kwargs.pop(param_name)
#    3000             except KeyError:
#    3001                 # We have no value for this parameter.  It's fine though,
#
# KeyboardInterrupt:

# %%
f_grid = u_discr.get_field_on_grid()

# %%
V = f_grid(get_params(opt_state))

# %%
plt.imshow(V[...,0].real, cmap="seismic", vmin=-2, vmax=2)
plt.colorbar()

# %%
plt.plot(jnp.log10(jnp.asarray(losshistory)))
